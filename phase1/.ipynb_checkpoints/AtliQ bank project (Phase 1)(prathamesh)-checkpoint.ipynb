# %% [markdown]
# # Atliq bank project
# # Phase 1

# %%
import pandas as pd
from matplotlib import pyplot  as plt 
import seaborn as sns

# %%
df_cust = pd.read_csv("datasets/customers.csv")
df_cs = pd.read_csv("datasets/customers.csv")
df_trans = pd.read_csv("datasets/transactions.csv")
df_cust.head()
# Out:
#    cust_id            name  gender  age location      occupation  \
# 0        1   Manya Acharya  Female    2     City  Business Owner
# 1        2   Anjali Pandey  Female   47     City      Consultant
# 2        3  Aaryan Chauhan    Male   21     City      Freelancer
# 3        4      Rudra Bali    Male   24    Rural      Freelancer
# 4        5    Advait Malik    Male   48     City      Consultant
#
#    annual_income marital_status
# 0       358211.0        Married
# 1        65172.0         Single
# 2        22378.0        Married
# 3        33563.0        Married
# 4        39406.0        Married

# %%
df_cs.head()
# Out:
#    cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 0        1           749            0.585171           19571.0
# 1        2           587            0.107928          161644.0
# 2        3           544            0.854807             513.0
# 3        4           504            0.336938             224.0
# 4        5           708            0.586151           18090.0
#
#    credit_inquiries_last_6_months  credit_limit
# 0                             0.0       40000.0
# 1                             2.0        1250.0
# 2                             4.0        1000.0
# 3                             2.0        1000.0
# 4                             2.0       40000.0

# %%
df_trans.head()
# Out:
#    tran_id  cust_id   tran_date  tran_amount  platform   product_category  \
# 0        1      705  2023-01-01           63  Flipkart        Electronics
# 1        2      385  2023-01-01           99   Alibaba  Fashion & Apparel
# 2        3      924  2023-01-01          471   Shopify             Sports
# 3        4      797  2023-01-01           33   Shopify  Fashion & Apparel
# 4        5      482  2023-01-01           68    Amazon  Fashion & Apparel
#
#   payment_type
# 0      Phonepe
# 1  Credit Card
# 2      Phonepe
# 3         Gpay
# 4  Net Banking

# %% [markdown]
# **Importing from mysql file**

# %%
import mysql.connector
conn = mysql.connector.connect(
    host = "localhost",
    user = "root",
    passwd = "root",
    database = "e_master_card"

)
query1 = "SELECT * FROM e_master_card.transactions"
df_strans = pd.read_sql_query(query1, conn)
# Out:
# C:\Users\prath\AppData\Local\Temp\ipykernel_13220\1017927109.py:10: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_strans = pd.read_sql_query(query1, conn)

# %%
df_strans.head()
# Out:
#    tran_id  cust_id   tran_date  tran_amount  platform   product_category  \
# 0        1      705  2023-01-01           63  Flipkart        Electronics
# 1        2      385  2023-01-01           99   Alibaba  Fashion & Apparel
# 2        3      924  2023-01-01          471   Shopify             Sports
# 3        4      797  2023-01-01           33   Shopify  Fashion & Apparel
# 4        5      482  2023-01-01           68    Amazon  Fashion & Apparel
#
#   payment_type
# 0      Phonepe
# 1  Credit Card
# 2      Phonepe
# 3         Gpay
# 4  Net Banking

# %%
df_cust.describe()
# Out:
#            cust_id          age  annual_income
# count  1000.000000  1000.000000     950.000000
# mean    500.500000    36.405000  139410.314737
# std     288.819436    15.666155  112416.802007
# min       1.000000     1.000000       2.000000
# 25%     250.750000    26.000000   47627.500000
# 50%     500.500000    32.000000  112218.500000
# 75%     750.250000    46.000000  193137.500000
# max    1000.000000   135.000000  449346.000000

# %% [markdown]
# # Data Cleaning

# %%
df_cust.isnull().sum()
# Out:
# cust_id            0
# name               0
# gender             0
# age                0
# location           0
# occupation         0
# annual_income     50
# marital_status     0
# dtype: int64

# %%
df_cust[df_cust.annual_income.isna()].head()
# Out:
#      cust_id               name  gender  age location           occupation  \
# 14        15      Sanjana Malik  Female   25    Rural               Artist
# 82        83  Reyansh Mukherjee    Male   27     City           Freelancer
# 97        98         Virat Puri    Male   47   Suburb       Business Owner
# 102      103         Aarav Shah    Male   32     City       Data Scientist
# 155      156       Kiaan Saxena    Male   24     City  Fullstack Developer
#
#      annual_income marital_status
# 14             NaN        Married
# 82             NaN         Single
# 97             NaN        Married
# 102            NaN        Married
# 155            NaN        Married

# %%
df_cust.annual_income.median()
# Out:
# np.float64(112218.5)

# %%
df_cust[df_cust.occupation == "Artist"].annual_income.median()
# Out:
# np.float64(45794.0)

# %%
occupation_wise_median_income = df_cust.groupby("occupation").annual_income.median()
occupation_wise_median_income
# Out:
# occupation
# Accountant              65265.0
# Artist                  45794.0
# Business Owner         261191.5
# Consultant              58017.0
# Data Scientist         135759.0
# Freelancer              46759.0
# Fullstack Developer     76774.0
# Name: annual_income, dtype: float64

# %% [markdown]
# **Dealing with null values**

# %%
df_cust["annual_income"] = df_cust.apply( 
    lambda row: occupation_wise_median_income[row["occupation"]] if pd.isnull(row["annual_income"]) else row["annual_income"],
    axis = 1
)

# %%
df_cust.isna().sum()
# Out:
# cust_id           0
# name              0
# gender            0
# age               0
# location          0
# occupation        0
# annual_income     0
# marital_status    0
# dtype: int64

# %%
df_cust.head()
# Out:
#    cust_id            name  gender  age location      occupation  \
# 0        1   Manya Acharya  Female    2     City  Business Owner
# 1        2   Anjali Pandey  Female   47     City      Consultant
# 2        3  Aaryan Chauhan    Male   21     City      Freelancer
# 3        4      Rudra Bali    Male   24    Rural      Freelancer
# 4        5    Advait Malik    Male   48     City      Consultant
#
#    annual_income marital_status
# 0       358211.0        Married
# 1        65172.0         Single
# 2        22378.0        Married
# 3        33563.0        Married
# 4        39406.0        Married

# %%
sns.histplot(df_cust.annual_income , kde = True ,label = "Data")
plt.title("Annual Income")
# Out:
# Text(0.5, 1.0, 'Annual Income')

# %% [markdown]
# **Dealin with outliers**

# %%
df_cust.describe()
# Out:
#            cust_id          age  annual_income
# count  1000.000000  1000.000000    1000.000000
# mean    500.500000    36.405000  138916.765500
# std     288.819436    15.666155  110969.408643
# min       1.000000     1.000000       2.000000
# 25%     250.750000    26.000000   48229.500000
# 50%     500.500000    32.000000  113416.000000
# 75%     750.250000    46.000000  192614.000000
# max    1000.000000   135.000000  449346.000000

# %%
df_cust[df_cust["annual_income"] < 100 ]
# Out:
#      cust_id            name  gender  age location           occupation  \
# 31        32     Veer Mistry    Male   50     City       Business Owner
# 262      263   Vivaan Tandon    Male   53   Suburb       Business Owner
# 316      317   Yuvraj Saxena    Male   47     City           Consultant
# 333      334    Avani Khanna  Female   29     City       Data Scientist
# 340      341     Priya Sinha  Female   33    Rural  Fullstack Developer
# 543      544    Advait Batra    Male   54     City           Consultant
# 592      593    Priya Gandhi  Female   32     City       Business Owner
# 633      634   Rudra Mehtani    Male   26     City       Data Scientist
# 686      687  Vihaan Jaiswal    Male   40     City       Business Owner
# 696      697      Ishan Negi    Male   47     City           Consultant
#
#      annual_income marital_status
# 31            50.0        Married
# 262           50.0        Married
# 316           50.0        Married
# 333           50.0        Married
# 340           50.0        Married
# 543            2.0        Married
# 592           50.0        Married
# 633            2.0        Married
# 686            2.0        Married
# 696           20.0        Married

# %%
for index , row  in df_cust.iterrows() :
    if row["annual_income"] < 100 :
        df_cust.at[index , "annual_income"] = occupation_wise_median_income[row["occupation"]]

# %%
occupation_wise_average_income = df_cust.groupby("occupation").annual_income.mean()
occupation_wise_average_income
# Out:
# occupation
# Accountant              64123.562500
# Artist                  45309.236842
# Business Owner         268447.368512
# Consultant              60703.154639
# Data Scientist         137021.266304
# Freelancer              76327.508772
# Fullstack Developer     78727.972973
# Name: annual_income, dtype: float64

# %%
df_cust[df_cust["annual_income"] < 100 ]
# Out:
# Empty DataFrame
# Columns: [cust_id, name, gender, age, location, occupation, annual_income, marital_status]
# Index: []

# %%
occupation_wise_average_income.index
# Out:
# Index(['Accountant', 'Artist', 'Business Owner', 'Consultant',
#        'Data Scientist', 'Freelancer', 'Fullstack Developer'],
#       dtype='object', name='occupation')

# %%
occupation_wise_average_income.values
# Out:
# array([ 64123.5625    ,  45309.23684211, 268447.36851211,  60703.15463918,
#        137021.26630435,  76327.50877193,  78727.97297297])

# %%
colors = sns.color_palette("hsv")
sns.barplot(x=occupation_wise_average_income.index, y=occupation_wise_average_income.values , palette = colors)

# Adding labels and title to make the plot more informative
plt.xlabel("Occupation")
plt.ylabel("Average Annual Income")
plt.title("Occupation-wise Average Annual Income")
plt.xticks(rotation = 45)

# Displaying the plot
plt.show()
# Out:
# C:\Users\prath\AppData\Local\Temp\ipykernel_13220\1745224410.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=occupation_wise_average_income.index, y=occupation_wise_average_income.values , palette = colors)
# C:\Users\prath\AppData\Local\Temp\ipykernel_13220\1745224410.py:2: UserWarning:
# The palette list has fewer values (6) than needed (7) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(x=occupation_wise_average_income.index, y=occupation_wise_average_income.values , palette = colors)

# %%
categorical_columns = ["gender","marital_status","location","occupation"]
for col in categorical_columns:
    average_income_per_group = df_cust.groupby(col)["annual_income"].mean().sort_values()
    sns.barplot(x=average_income_per_group.index, y=average_income_per_group.values , palette = "hsv")
    plt.ylabel("Average Annual Income")
    plt.title(" Average Annual Income")
    plt.xticks(rotation = 45)
    plt.show()
# Out:
# C:\Users\prath\AppData\Local\Temp\ipykernel_13220\450955377.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=average_income_per_group.index, y=average_income_per_group.values , palette = "hsv")
# C:\Users\prath\AppData\Local\Temp\ipykernel_13220\450955377.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=average_income_per_group.index, y=average_income_per_group.values , palette = "hsv")
# C:\Users\prath\AppData\Local\Temp\ipykernel_13220\450955377.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=average_income_per_group.index, y=average_income_per_group.values , palette = "hsv")
# C:\Users\prath\AppData\Local\Temp\ipykernel_13220\450955377.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=average_income_per_group.index, y=average_income_per_group.values , palette = "hsv")

# %%
categorical_columns = ["gender", "marital_status", "location", "occupation"]

# Create a 2x2 grid of subplots
fig, axes = plt.subplots(2, 2, figsize=(15, 10))
axes = axes.flatten()  # Flatten the array of axes for easy iteration

for i, col in enumerate(categorical_columns):
    average_income_per_group = df_cust.groupby(col)["annual_income"].mean().sort_values()
    sns.barplot(x=average_income_per_group.index, y=average_income_per_group.values, palette="hsv", ax=axes[i])
    axes[i].set_ylabel("Average Annual Income")
    axes[i].set_title(f"Average Annual Income by {col.capitalize()}")
    axes[i].tick_params(axis='x', rotation=45)

# Adjust layout
plt.tight_layout()
plt.show()
# Out:
# C:\Users\prath\AppData\Local\Temp\ipykernel_13220\1464857764.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=average_income_per_group.index, y=average_income_per_group.values, palette="hsv", ax=axes[i])
# C:\Users\prath\AppData\Local\Temp\ipykernel_13220\1464857764.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=average_income_per_group.index, y=average_income_per_group.values, palette="hsv", ax=axes[i])
# C:\Users\prath\AppData\Local\Temp\ipykernel_13220\1464857764.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=average_income_per_group.index, y=average_income_per_group.values, palette="hsv", ax=axes[i])
# C:\Users\prath\AppData\Local\Temp\ipykernel_13220\1464857764.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=average_income_per_group.index, y=average_income_per_group.values, palette="hsv", ax=axes[i])

# %%
df_cust[df_cust["age"].isna()]
#No na values in age column
# Out:
# Empty DataFrame
# Columns: [cust_id, name, gender, age, location, occupation, annual_income, marital_status]
# Index: []

# %%
df_cust["age"].describe()
# Out:
# count    1000.000000
# mean       36.405000
# std        15.666155
# min         1.000000
# 25%        26.000000
# 50%        32.000000
# 75%        46.000000
# max       135.000000
# Name: age, dtype: float64

# %%
df_cust[(df_cust["age"] > 80) | (df_cust["age"] < 15 ) ]
# Out:
#      cust_id             name  gender  age location           occupation  \
# 0          1    Manya Acharya  Female    2     City       Business Owner
# 41        42      Aaryan Shah    Male  110     City               Artist
# 165      166        Sia Dutta  Female    1     City           Freelancer
# 174      175     Rohan Sharma    Male  110     City           Freelancer
# 222      223      Arjun Batra    Male  110   Suburb           Freelancer
# 277      278     Aarav Tandon    Male  110     City           Consultant
# 295      296     Ayush Pandey    Male    1    Rural           Accountant
# 325      326       Virat Goel    Male  110     City           Accountant
# 610      611      Rehan Verma    Male  135    Rural       Business Owner
# 692      693        Dhruv Jha    Male    1     City       Business Owner
# 703      704     Aanya Sharma  Female  110     City           Freelancer
# 709      710      Anika Verma  Female  110     City       Data Scientist
# 728      729      Rehan Yadav    Male  135     City       Business Owner
# 832      833        Ridhi Raj  Female  110     City  Fullstack Developer
# 845      846    Rohan Jaiswal    Male    1     City           Consultant
# 855      856     Aanya Taneja  Female    2     City  Fullstack Developer
# 895      896  Krishna Goswami    Male    1     City           Freelancer
# 923      924      Kunal Patel    Male  110     City           Freelancer
# 951      952     Virat Shetty    Male  135     City       Data Scientist
# 991      992        Arya Dube    Male  135     City  Fullstack Developer
#
#      annual_income marital_status
# 0         358211.0        Married
# 41          7621.0        Married
# 165        39721.0         Single
# 174        23723.0        Married
# 222       210987.0        Married
# 277        96522.0         Single
# 295        55254.0        Married
# 325        61021.0         Single
# 610       444776.0        Married
# 692        83045.0        Married
# 703        43404.0         Single
# 709        98417.0        Married
# 728       382836.0        Married
# 832        95379.0         Single
# 845        20838.0        Married
# 855        30689.0        Married
# 895        31533.0        Married
# 923        51629.0        Married
# 951        49677.0        Married
# 991        93267.0         Single

# %%
occupation_wise_median_age = df_cust.groupby("occupation").age.median()
occupation_wise_median_age
# Out:
# occupation
# Accountant             31.5
# Artist                 26.0
# Business Owner         51.0
# Consultant             46.0
# Data Scientist         32.0
# Freelancer             24.0
# Fullstack Developer    27.5
# Name: age, dtype: float64

# %%
for index, row in df_cust.iterrows():
    if row["age"] > 80 or row["age"] < 15:
        df_cust.at[index, "age"] = occupation_wise_median_age[row["occupation"]]
# Out:
# C:\Users\prath\AppData\Local\Temp\ipykernel_13220\3801633991.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '31.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_cust.at[index, "age"] = occupation_wise_median_age[row["occupation"]]

# %%
df_cust["age"].describe()
# Out:
# count    1000.000000
# mean       35.541500
# std        12.276634
# min        18.000000
# 25%        26.000000
# 50%        32.000000
# 75%        44.250000
# max        64.000000
# Name: age, dtype: float64

# %%
df_cust[(df_cust["age"] > 80) | (df_cust["age"] < 15 ) ]
# Out:
# Empty DataFrame
# Columns: [cust_id, name, gender, age, location, occupation, annual_income, marital_status]
# Index: []

# %%
sns.histplot(df_cust.age , kde = True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %% [markdown]
# **Data visualization age column**

# %%
bin = [18,25,48,65]
labels = ["18-25","26-48","49-65"]
df_cust["age_group"] = pd.cut(df_cust["age"],bins = bin , labels = labels)

# %%
df_cust.head()
# Out:
#    cust_id            name  gender   age location      occupation  \
# 0        1   Manya Acharya  Female  51.0     City  Business Owner
# 1        2   Anjali Pandey  Female  47.0     City      Consultant
# 2        3  Aaryan Chauhan    Male  21.0     City      Freelancer
# 3        4      Rudra Bali    Male  24.0    Rural      Freelancer
# 4        5    Advait Malik    Male  48.0     City      Consultant
#
#    annual_income marital_status age_group
# 0       358211.0        Married     49-65
# 1        65172.0         Single     26-48
# 2        22378.0        Married     18-25
# 3        33563.0        Married     18-25
# 4        39406.0        Married     26-48

# %%
age_distribution = df_cust["age_group"].value_counts()
plt.pie(age_distribution , labels = labels , shadow = True ,
        autopct='%1.1f%%',
        explode = (0.1,0.0,0.0) ,startangle = 120)
plt.title('Age wise customer distribution')
plt.show()

# %% [markdown]
# # Gender and age analysis

# %%
df_cust['gender'].value_counts()
# Out:
# gender
# Male      674
# Female    326
# Name: count, dtype: int64

# %%
df_cust["location"].value_counts()
# Out:
# location
# City      683
# Suburb    232
# Rural      85
# Name: count, dtype: int64

# %%
customer_location_gender = df_cust.groupby(["location","gender"]).size().unstack(fill_value = 0)
customer_location_gender.head()
# Out:
# gender    Female  Male
# location
# City         226   457
# Rural         26    59
# Suburb        74   158

# %%
customer_location_gender.plot(kind = 'bar' , stacked = True)
plt.legend(title='Gender', bbox_to_anchor=(1, 1))
plt.xticks(rotation = 45)
plt.title('Location and gender wise customer distribution')
plt.xlabel("Location Type")
plt.ylabel('No of customers')
plt.show()

# %% [markdown]
# # Exploring credit score table

# %%
df_cs.head()
# Out:
#    cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 0        1           749            0.585171           19571.0
# 1        2           587            0.107928          161644.0
# 2        3           544            0.854807             513.0
# 3        4           504            0.336938             224.0
# 4        5           708            0.586151           18090.0
#
#    credit_inquiries_last_6_months  credit_limit
# 0                             0.0       40000.0
# 1                             2.0        1250.0
# 2                             4.0        1000.0
# 3                             2.0        1000.0
# 4                             2.0       40000.0

# %%
df_cs.shape
# Out:
# (1004, 6)

# %%
df_cust.shape
# Out:
# (1000, 9)

# %%
df_cs["cust_id"].nunique()
# Out:
# 1000

# %%
df_cs[df_cs["cust_id"].duplicated(keep = False)]
# Out:
#      cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 516      517           308                 NaN               NaN
# 517      517           308            0.113860              33.0
# 569      569           344                 NaN               NaN
# 570      569           344            0.112599              37.0
# 607      606           734                 NaN               NaN
# 608      606           734            0.193418            4392.0
# 664      662           442                 NaN               NaN
# 665      662           442            0.856039             266.0
#
#      credit_inquiries_last_6_months  credit_limit
# 516                             NaN           NaN
# 517                             3.0         500.0
# 569                             NaN           NaN
# 570                             0.0         500.0
# 607                             NaN           NaN
# 608                             1.0       40000.0
# 664                             NaN           NaN
# 665                             2.0         500.0

# %%
df_cs_clean1 = df_cs.drop_duplicates(subset = 'cust_id',keep = "last")
df_cs_clean1.head()
# Out:
#    cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 0        1           749            0.585171           19571.0
# 1        2           587            0.107928          161644.0
# 2        3           544            0.854807             513.0
# 3        4           504            0.336938             224.0
# 4        5           708            0.586151           18090.0
#
#    credit_inquiries_last_6_months  credit_limit
# 0                             0.0       40000.0
# 1                             2.0        1250.0
# 2                             4.0        1000.0
# 3                             2.0        1000.0
# 4                             2.0       40000.0

# %%
df_cs_clean1.shape
# Out:
# (1000, 6)

# %%
df_cs_clean1["cust_id"].nunique()
# Out:
# 1000

# %%
df_cs_clean1[df_cs_clean1["cust_id"].duplicated(keep = False)]
# Out:
# Empty DataFrame
# Columns: [cust_id, credit_score, credit_utilisation, outstanding_debt, credit_inquiries_last_6_months, credit_limit]
# Index: []

# %%
df_cs_clean1.isnull().sum()
# Out:
# cust_id                            0
# credit_score                       0
# credit_utilisation                 0
# outstanding_debt                   0
# credit_inquiries_last_6_months     0
# credit_limit                      65
# dtype: int64

# %%
df_cs_clean1[df_cs_clean1['credit_limit'].isnull()]
# Out:
#      cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 10        11           679            0.557450            9187.0
# 35        36           790            0.112535            4261.0
# 37        38           514            0.296971             238.0
# 45        46           761            0.596041           24234.0
# 64        65           734            0.473715           13631.0
# ..       ...           ...                 ...               ...
# 912      909           479            0.487555             320.0
# 931      928           311            0.832244             316.0
# 948      945           526            0.272734             227.0
# 954      951           513            0.175914             131.0
# 957      954           783            0.867421           46451.0
#
#      credit_inquiries_last_6_months  credit_limit
# 10                              2.0           NaN
# 35                              1.0           NaN
# 37                              2.0           NaN
# 45                              2.0           NaN
# 64                              0.0           NaN
# ..                              ...           ...
# 912                             3.0           NaN
# 931                             2.0           NaN
# 948                             1.0           NaN
# 954                             3.0           NaN
# 957                             0.0           NaN
#
# [65 rows x 6 columns]

# %%
df_cs_clean1.credit_limit.value_counts()
# Out:
# credit_limit
# 500.0      229
# 60000.0    186
# 40000.0    137
# 1500.0     100
# 1000.0      90
# 750.0       76
# 1250.0      75
# 20000.0     42
# Name: count, dtype: int64

# %%
plt.figure(figsize = (20,7))
plt.scatter(df_cs_clean1.credit_limit,df_cs_clean1.credit_score)
plt.grid(True)
plt.title("credit score vs credit limit")
plt.xlabel("credit score")
plt.ylabel("credit limit")
plt.legend()
plt.show()
# Out:
# C:\Users\prath\AppData\Local\Temp\ipykernel_13220\1718606366.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
df_cs_clean1["credit_score"].nunique()
# Out:
# 419

# %%
bins = [300,350,400,450,500,550,600,650,700,750,800]
label = [f"{start}-{end-1}"for start , end in zip(bins, bins[1:])]
label
# Out:
# ['300-349',
#  '350-399',
#  '400-449',
#  '450-499',
#  '500-549',
#  '550-599',
#  '600-649',
#  '650-699',
#  '700-749',
#  '750-799']

# %%
df_cs_clean1["credit_score_range"] = pd.cut(df_cs_clean1.credit_score ,
                                            bins = bins , 
                                            labels=label , 
                                            include_lowest=True , 
                                            right = True
                                            )
df_cs_clean1.head()
# Out:
# C:\Users\prath\AppData\Local\Temp\ipykernel_13220\3315088921.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cs_clean1["credit_score_range"] = pd.cut(df_cs_clean1.credit_score ,
#    cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 0        1           749            0.585171           19571.0
# 1        2           587            0.107928          161644.0
# 2        3           544            0.854807             513.0
# 3        4           504            0.336938             224.0
# 4        5           708            0.586151           18090.0
#
#    credit_inquiries_last_6_months  credit_limit credit_score_range
# 0                             0.0       40000.0            700-749
# 1                             2.0        1250.0            550-599
# 2                             4.0        1000.0            500-549
# 3                             2.0        1000.0            500-549
# 4                             2.0       40000.0            700-749

# %%
df_cs_clean1[df_cs_clean1["credit_score_range"].isnull()]
# Out:
# Empty DataFrame
# Columns: [cust_id, credit_score, credit_utilisation, outstanding_debt, credit_inquiries_last_6_months, credit_limit, credit_score_range]
# Index: []

# %%
df_cs_clean1[df_cs_clean1["credit_score_range"]== "700-749"]
# Out:
#       cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 0           1           749            0.585171           19571.0
# 4           5           708            0.586151           18090.0
# 6           7           747            0.523965           15544.0
# 16         17           702            0.894423           18444.0
# 27         28           729            0.149748            3453.0
# ...       ...           ...                 ...               ...
# 969       966           720            0.203742            6159.0
# 970       967           739            0.845474           23929.0
# 991       988           739            0.435891            9283.0
# 994       991           709            0.718484           15473.0
# 1002      999           725            0.249670            6973.0
#
#       credit_inquiries_last_6_months  credit_limit credit_score_range
# 0                                0.0       40000.0            700-749
# 4                                2.0       40000.0            700-749
# 6                                4.0       40000.0            700-749
# 16                               0.0       40000.0            700-749
# 27                               2.0       40000.0            700-749
# ...                              ...           ...                ...
# 969                              4.0       40000.0            700-749
# 970                              4.0       40000.0            700-749
# 991                              4.0       40000.0            700-749
# 994                              4.0       40000.0            700-749
# 1002                             2.0       40000.0            700-749
#
# [148 rows x 7 columns]

# %%
df_cs_clean1.describe()
# Out:
#            cust_id  credit_score  credit_utilisation  outstanding_debt  \
# count  1000.000000   1000.000000         1000.000000       1000.000000
# mean    500.500000    589.182000            0.498950       9683.597000
# std     288.819436    152.284929            0.233139      25255.893671
# min       1.000000    300.000000            0.103761         33.000000
# 25%     250.750000    460.000000            0.293917        221.000000
# 50%     500.500000    601.500000            0.487422        550.000000
# 75%     750.250000    738.000000            0.697829      11819.500000
# max    1000.000000    799.000000            0.899648     209901.000000
#
#        credit_inquiries_last_6_months  credit_limit
# count                     1000.000000    935.000000
# mean                         1.955000  19235.561497
# std                          1.414559  24489.997195
# min                          0.000000    500.000000
# 25%                          1.000000    750.000000
# 50%                          2.000000   1250.000000
# 75%                          3.000000  40000.000000
# max                          4.000000  60000.000000

# %%
df_cs_clean1[df_cs_clean1["credit_limit"].isnull()]
# Out:
#      cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 10        11           679            0.557450            9187.0
# 35        36           790            0.112535            4261.0
# 37        38           514            0.296971             238.0
# 45        46           761            0.596041           24234.0
# 64        65           734            0.473715           13631.0
# ..       ...           ...                 ...               ...
# 912      909           479            0.487555             320.0
# 931      928           311            0.832244             316.0
# 948      945           526            0.272734             227.0
# 954      951           513            0.175914             131.0
# 957      954           783            0.867421           46451.0
#
#      credit_inquiries_last_6_months  credit_limit credit_score_range
# 10                              2.0           NaN            650-699
# 35                              1.0           NaN            750-799
# 37                              2.0           NaN            500-549
# 45                              2.0           NaN            750-799
# 64                              0.0           NaN            700-749
# ..                              ...           ...                ...
# 912                             3.0           NaN            450-499
# 931                             2.0           NaN            300-349
# 948                             1.0           NaN            500-549
# 954                             3.0           NaN            500-549
# 957                             0.0           NaN            750-799
#
# [65 rows x 7 columns]

# %%
df_mode = df_cs_clean1.groupby(df_cs_clean1["credit_score_range"])["credit_limit"].agg( lambda x : x.mode().iloc[0]).reset_index()
df_mode
# Out:
# C:\Users\prath\AppData\Local\Temp\ipykernel_13220\3407392535.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_mode = df_cs_clean1.groupby(df_cs_clean1["credit_score_range"])["credit_limit"].agg( lambda x : x.mode().iloc[0]).reset_index()
#   credit_score_range  credit_limit
# 0            300-349         500.0
# 1            350-399         500.0
# 2            400-449         500.0
# 3            450-499         750.0
# 4            500-549        1000.0
# 5            550-599        1250.0
# 6            600-649        1500.0
# 7            650-699       20000.0
# 8            700-749       40000.0
# 9            750-799       60000.0

# %%
df_cs_clean2 = pd.merge(df_cs_clean1,df_mode,on = "credit_score_range", suffixes= ("","_mode"))
df_cs_clean2.head()
# Out:
#    cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 0        1           749            0.585171           19571.0
# 1        2           587            0.107928          161644.0
# 2        3           544            0.854807             513.0
# 3        4           504            0.336938             224.0
# 4        5           708            0.586151           18090.0
#
#    credit_inquiries_last_6_months  credit_limit credit_score_range  \
# 0                             0.0       40000.0            700-749
# 1                             2.0        1250.0            550-599
# 2                             4.0        1000.0            500-549
# 3                             2.0        1000.0            500-549
# 4                             2.0       40000.0            700-749
#
#    credit_limit_mode
# 0            40000.0
# 1             1250.0
# 2             1000.0
# 3             1000.0
# 4            40000.0

# %%
df_cs_clean2['credit_limit_mode'].isnull().sum()
# Out:
# np.int64(0)

# %%
df_cs_clean2["credit_limit"].isnull().sum()
# Out:
# np.int64(65)

# %%
df_cs_clean2["credit_limit"].fillna(df_cs_clean2['credit_limit_mode'], inplace = True)
# Out:
# C:\Users\prath\AppData\Local\Temp\ipykernel_13220\147214336.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_cs_clean2["credit_limit"].fillna(df_cs_clean2['credit_limit_mode'], inplace = True)

# %%
df_cs_clean2[df_cs_clean2["credit_limit"].isnull()]
# Out:
# Empty DataFrame
# Columns: [cust_id, credit_score, credit_utilisation, outstanding_debt, credit_inquiries_last_6_months, credit_limit, credit_score_range, credit_limit_mode]
# Index: []

# %%
df_cs_clean2["credit_limit"].isnull().sum()
# Out:
# np.int64(0)

# %%
df_cs_clean3 = df_cs_clean2.copy()

# %%
df_cs_clean3.describe()
# Out:
#            cust_id  credit_score  credit_utilisation  outstanding_debt  \
# count  1000.000000   1000.000000         1000.000000       1000.000000
# mean    500.500000    589.182000            0.498950       9683.597000
# std     288.819436    152.284929            0.233139      25255.893671
# min       1.000000    300.000000            0.103761         33.000000
# 25%     250.750000    460.000000            0.293917        221.000000
# 50%     500.500000    601.500000            0.487422        550.000000
# 75%     750.250000    738.000000            0.697829      11819.500000
# max    1000.000000    799.000000            0.899648     209901.000000
#
#        credit_inquiries_last_6_months  credit_limit  credit_limit_mode
# count                     1000.000000   1000.000000        1000.000000
# mean                         1.955000  19733.500000       19733.500000
# std                          1.414559  24717.629112       24717.629112
# min                          0.000000    500.000000         500.000000
# 25%                          1.000000    750.000000         750.000000
# 50%                          2.000000   1500.000000        1500.000000
# 75%                          3.000000  40000.000000       40000.000000
# max                          4.000000  60000.000000       60000.000000

# %%
df_cs_clean3[df_cs_clean3['outstanding_debt'] < df_cs_clean3['credit_limit']]
# Out:
#      cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 0          1           749            0.585171           19571.0
# 2          3           544            0.854807             513.0
# 3          4           504            0.336938             224.0
# 4          5           708            0.586151           18090.0
# 5          6           442            0.705409             246.0
# ..       ...           ...                 ...               ...
# 995      996           564            0.702963             688.0
# 996      997           774            0.465462           17139.0
# 997      998           529            0.585856             386.0
# 998      999           725            0.249670            6973.0
# 999     1000           775            0.696050           33956.0
#
#      credit_inquiries_last_6_months  credit_limit credit_score_range  \
# 0                               0.0       40000.0            700-749
# 2                               4.0        1000.0            500-549
# 3                               2.0        1000.0            500-549
# 4                               2.0       40000.0            700-749
# 5                               4.0         500.0            400-449
# ..                              ...           ...                ...
# 995                             2.0        1250.0            550-599
# 996                             0.0       60000.0            750-799
# 997                             3.0        1000.0            500-549
# 998                             2.0       40000.0            700-749
# 999                             1.0       60000.0            750-799
#
#      credit_limit_mode
# 0              40000.0
# 2               1000.0
# 3               1000.0
# 4              40000.0
# 5                500.0
# ..                 ...
# 995             1250.0
# 996            60000.0
# 997             1000.0
# 998            40000.0
# 999            60000.0
#
# [980 rows x 8 columns]

# %%
df_cs_clean3.loc[df_cs_clean3['outstanding_debt'] > df_cs_clean3['credit_limit'], 'outstanding_debt'] = df_cs_clean3['credit_limit']

# %%
df_cs_clean3[df_cs_clean3['outstanding_debt'] > df_cs_clean3['credit_limit']]
# Out:
# Empty DataFrame
# Columns: [cust_id, credit_score, credit_utilisation, outstanding_debt, credit_inquiries_last_6_months, credit_limit, credit_score_range, credit_limit_mode]
# Index: []

# %%
df_cs_clean3.head()
# Out:
#    cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 0        1           749            0.585171           19571.0
# 1        2           587            0.107928            1250.0
# 2        3           544            0.854807             513.0
# 3        4           504            0.336938             224.0
# 4        5           708            0.586151           18090.0
#
#    credit_inquiries_last_6_months  credit_limit credit_score_range  \
# 0                             0.0       40000.0            700-749
# 1                             2.0        1250.0            550-599
# 2                             4.0        1000.0            500-549
# 3                             2.0        1000.0            500-549
# 4                             2.0       40000.0            700-749
#
#    credit_limit_mode
# 0            40000.0
# 1             1250.0
# 2             1000.0
# 3             1000.0
# 4            40000.0

# %% [markdown]
# **Getting correlation between various columns**

# %%
df_cs_clean3.head()
# Out:
#    cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 0        1           749            0.585171           19571.0
# 1        2           587            0.107928            1250.0
# 2        3           544            0.854807             513.0
# 3        4           504            0.336938             224.0
# 4        5           708            0.586151           18090.0
#
#    credit_inquiries_last_6_months  credit_limit credit_score_range  \
# 0                             0.0       40000.0            700-749
# 1                             2.0        1250.0            550-599
# 2                             4.0        1000.0            500-549
# 3                             2.0        1000.0            500-549
# 4                             2.0       40000.0            700-749
#
#    credit_limit_mode
# 0            40000.0
# 1             1250.0
# 2             1000.0
# 3             1000.0
# 4            40000.0

# %%
df_cust.head()
# Out:
#    cust_id            name  gender   age location      occupation  \
# 0        1   Manya Acharya  Female  51.0     City  Business Owner
# 1        2   Anjali Pandey  Female  47.0     City      Consultant
# 2        3  Aaryan Chauhan    Male  21.0     City      Freelancer
# 3        4      Rudra Bali    Male  24.0    Rural      Freelancer
# 4        5    Advait Malik    Male  48.0     City      Consultant
#
#    annual_income marital_status age_group
# 0       358211.0        Married     49-65
# 1        65172.0         Single     26-48
# 2        22378.0        Married     18-25
# 3        33563.0        Married     18-25
# 4        39406.0        Married     26-48

# %%
df_merge = pd.merge(df_cust,df_cs_clean3, on = "cust_id")
df_merge.head()
# Out:
#    cust_id            name  gender   age location      occupation  \
# 0        1   Manya Acharya  Female  51.0     City  Business Owner
# 1        2   Anjali Pandey  Female  47.0     City      Consultant
# 2        3  Aaryan Chauhan    Male  21.0     City      Freelancer
# 3        4      Rudra Bali    Male  24.0    Rural      Freelancer
# 4        5    Advait Malik    Male  48.0     City      Consultant
#
#    annual_income marital_status age_group  credit_score  credit_utilisation  \
# 0       358211.0        Married     49-65           749            0.585171
# 1        65172.0         Single     26-48           587            0.107928
# 2        22378.0        Married     18-25           544            0.854807
# 3        33563.0        Married     18-25           504            0.336938
# 4        39406.0        Married     26-48           708            0.586151
#
#    outstanding_debt  credit_inquiries_last_6_months  credit_limit  \
# 0           19571.0                             0.0       40000.0
# 1            1250.0                             2.0        1250.0
# 2             513.0                             4.0        1000.0
# 3             224.0                             2.0        1000.0
# 4           18090.0                             2.0       40000.0
#
#   credit_score_range  credit_limit_mode
# 0            700-749            40000.0
# 1            550-599             1250.0
# 2            500-549             1000.0
# 3            500-549             1000.0
# 4            700-749            40000.0

# %%
numerical_columns = ["age","annual_income","credit_score","credit_utilisation","outstanding_debt","credit_inquiries_last_6_months","credit_limit"]
correlation_matrix = df_merge[numerical_columns].corr()
correlation_matrix
# Out:
#                                      age  annual_income  credit_score  \
# age                             1.000000       0.619037      0.444917
# annual_income                   0.619037       1.000000      0.575751
# credit_score                    0.444917       0.575751      1.000000
# credit_utilisation             -0.027713      -0.086368     -0.070445
# outstanding_debt                0.444301       0.555661      0.680654
# credit_inquiries_last_6_months -0.025831       0.002747     -0.001226
# credit_limit                    0.510980       0.684780      0.847951
#
#                                 credit_utilisation  outstanding_debt  \
# age                                      -0.027713          0.444301
# annual_income                            -0.086368          0.555661
# credit_score                             -0.070445          0.680654
# credit_utilisation                        1.000000          0.192838
# outstanding_debt                          0.192838          1.000000
# credit_inquiries_last_6_months           -0.013952          0.019793
# credit_limit                             -0.080504          0.810581
#
#                                 credit_inquiries_last_6_months  credit_limit
# age                                                  -0.025831      0.510980
# annual_income                                         0.002747      0.684780
# credit_score                                         -0.001226      0.847951
# credit_utilisation                                   -0.013952     -0.080504
# outstanding_debt                                      0.019793      0.810581
# credit_inquiries_last_6_months                        1.000000      0.014716
# credit_limit                                          0.014716      1.000000

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title("Correlation heatmap")
plt.show()

# %% [markdown]
# # Data cleaning in transection column

# %%
df_trans.head()
# Out:
#    tran_id  cust_id   tran_date  tran_amount  platform   product_category  \
# 0        1      705  2023-01-01           63  Flipkart        Electronics
# 1        2      385  2023-01-01           99   Alibaba  Fashion & Apparel
# 2        3      924  2023-01-01          471   Shopify             Sports
# 3        4      797  2023-01-01           33   Shopify  Fashion & Apparel
# 4        5      482  2023-01-01           68    Amazon  Fashion & Apparel
#
#   payment_type
# 0      Phonepe
# 1  Credit Card
# 2      Phonepe
# 3         Gpay
# 4  Net Banking

# %%
df_trans.describe()
# Out:
#              tran_id        cust_id   tran_amount
# count  500000.000000  500000.000000  500000.00000
# mean   250000.500000     501.400428    3225.20733
# std    144337.711635     288.641924   13098.74276
# min         1.000000       1.000000       0.00000
# 25%    125000.750000     252.000000      64.00000
# 50%    250000.500000     502.000000     141.00000
# 75%    375000.250000     752.000000     397.00000
# max    500000.000000    1000.000000   69999.00000

# %%
df_trans.isnull().sum()
# Out:
# tran_id                0
# cust_id                0
# tran_date              0
# tran_amount            0
# platform            4941
# product_category       0
# payment_type           0
# dtype: int64

# %%
df_trans[df_trans["platform"].isnull()]
# Out:
#         tran_id  cust_id   tran_date  tran_amount platform   product_category  \
# 355         356       58  2023-01-01          237      NaN        Electronics
# 418         419      383  2023-01-01          338      NaN        Electronics
# 607         608      421  2023-01-01          700      NaN        Electronics
# 844         845      945  2023-01-01          493      NaN             Sports
# 912         913      384  2023-01-01           85      NaN  Fashion & Apparel
# ...         ...      ...         ...          ...      ...                ...
# 499579   499580      924  2023-09-05           31      NaN  Fashion & Apparel
# 499646   499647      944  2023-09-05        58445      NaN  Fashion & Apparel
# 499725   499726      620  2023-09-05           15      NaN             Sports
# 499833   499834      616  2023-09-05           97      NaN  Fashion & Apparel
# 499997   499998       57  2023-09-05          224      NaN   Garden & Outdoor
#
#        payment_type
# 355     Net Banking
# 418     Credit Card
# 607         Phonepe
# 844     Credit Card
# 912         Phonepe
# ...             ...
# 499579         Gpay
# 499646      Phonepe
# 499725  Net Banking
# 499833  Credit Card
# 499997      Phonepe
#
# [4941 rows x 7 columns]

# %%
df_trans["platform"].unique()
# Out:
# array(['Flipkart', 'Alibaba', 'Shopify', 'Amazon', 'Ebay', 'Meesho',
#        'Cred', nan], dtype=object)

# %%
platform_mode = df_trans["platform"].mode()[0]
platform_mode
# Out:
# 'Amazon'

# %%
sns.countplot(y="product_category",hue="platform",data = df_trans )
plt.show()

# %%
df_trans["platform"].fillna( platform_mode ,inplace = True)
# Out:
# C:\Users\prath\AppData\Local\Temp\ipykernel_13220\3293557153.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_trans["platform"].fillna( platform_mode ,inplace = True)

# %%
df_trans["platform"].fillna( platform_mode ,inplace = True)

# %%
df_trans.head()
# Out:
#    tran_id  cust_id   tran_date  tran_amount  platform   product_category  \
# 0        1      705  2023-01-01           63  Flipkart        Electronics
# 1        2      385  2023-01-01           99   Alibaba  Fashion & Apparel
# 2        3      924  2023-01-01          471   Shopify             Sports
# 3        4      797  2023-01-01           33   Shopify  Fashion & Apparel
# 4        5      482  2023-01-01           68    Amazon  Fashion & Apparel
#
#   payment_type
# 0      Phonepe
# 1  Credit Card
# 2      Phonepe
# 3         Gpay
# 4  Net Banking

# %%
df_trans.describe()
# Out:
#              tran_id        cust_id   tran_amount
# count  500000.000000  500000.000000  500000.00000
# mean   250000.500000     501.400428    3225.20733
# std    144337.711635     288.641924   13098.74276
# min         1.000000       1.000000       0.00000
# 25%    125000.750000     252.000000      64.00000
# 50%    250000.500000     502.000000     141.00000
# 75%    375000.250000     752.000000     397.00000
# max    500000.000000    1000.000000   69999.00000

# %% [markdown]
# **Transection amount cannot be zero**

# %%
df_trans_zero = df_trans[df_trans["tran_amount"] == 0]
df_trans_zero
# Out:
#         tran_id  cust_id   tran_date  tran_amount platform product_category  \
# 120         121      440  2023-01-01            0   Amazon      Electronics
# 141         142      839  2023-01-01            0   Amazon      Electronics
# 517         518      147  2023-01-01            0   Amazon      Electronics
# 533         534      891  2023-01-01            0   Amazon      Electronics
# 586         587      108  2023-01-01            0   Amazon      Electronics
# ...         ...      ...         ...          ...      ...              ...
# 499326   499327      695  2023-09-05            0   Amazon      Electronics
# 499494   499495      295  2023-09-05            0   Amazon      Electronics
# 499708   499709      141  2023-09-05            0   Amazon      Electronics
# 499928   499929        4  2023-09-05            0   Amazon      Electronics
# 499972   499973      224  2023-09-05            0   Amazon      Electronics
#
#        payment_type
# 120     Credit Card
# 141     Credit Card
# 517     Credit Card
# 533     Credit Card
# 586     Credit Card
# ...             ...
# 499326  Credit Card
# 499494  Credit Card
# 499708  Credit Card
# 499928  Credit Card
# 499972  Credit Card
#
# [4734 rows x 7 columns]

# %%
df_trans_zero[["platform","product_category","payment_type"]].value_counts()
# Out:
# platform  product_category  payment_type
# Amazon    Electronics       Credit Card     4734
# Name: count, dtype: int64

# %%
trans_1 = df_trans[(df_trans["platform"] == "Amazon")&(df_trans["product_category"] == "Electronics")&(df_trans["payment_type"] == "Credit Card")]
trans_1.head()
# Out:
#      tran_id  cust_id   tran_date  tran_amount platform product_category  \
# 109      110      887  2023-01-01          635   Amazon      Electronics
# 120      121      440  2023-01-01            0   Amazon      Electronics
# 141      142      839  2023-01-01            0   Amazon      Electronics
# 173      174      676  2023-01-01        60439   Amazon      Electronics
# 190      191      763  2023-01-01          697   Amazon      Electronics
#
#     payment_type
# 109  Credit Card
# 120  Credit Card
# 141  Credit Card
# 173  Credit Card
# 190  Credit Card

# %%
df_trans_without_zero = trans_1[trans_1["tran_amount"] > 0]
df_trans_without_zero.head()
# Out:
#      tran_id  cust_id   tran_date  tran_amount platform product_category  \
# 109      110      887  2023-01-01          635   Amazon      Electronics
# 173      174      676  2023-01-01        60439   Amazon      Electronics
# 190      191      763  2023-01-01          697   Amazon      Electronics
# 263      264      528  2023-01-01          421   Amazon      Electronics
# 311      312      936  2023-01-01          537   Amazon      Electronics
#
#     payment_type
# 109  Credit Card
# 173  Credit Card
# 190  Credit Card
# 263  Credit Card
# 311  Credit Card

# %%
trans_amt_median = df_trans_without_zero["tran_amount"].median()
trans_amt_median
# Out:
# np.float64(554.0)

# %%
df_trans["tran_amount"].replace(0,trans_amt_median,inplace = True)
# Out:
# C:\Users\prath\AppData\Local\Temp\ipykernel_13220\2413628742.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_trans["tran_amount"].replace(0,trans_amt_median,inplace = True)

# %%
df_trans[df_trans["tran_amount"] == 0]
# Out:
# Empty DataFrame
# Columns: [tran_id, cust_id, tran_date, tran_amount, platform, product_category, payment_type]
# Index: []

# %%
sns.histplot(df_trans["tran_amount"] , bins = 20 ,kde = True)
# Out:
# <Axes: xlabel='tran_amount', ylabel='Count'>

# %%
Q1 , Q3 = df_trans["tran_amount"].quantile([0.25,0.75])
IQR = Q3 - Q1
upper  = Q3 + 2*IQR
lower = Q1 - 2*IQR
upper , lower
# Out:
# (1107.0, -628.0)

# %%
df_trans_outliers = df_trans[df_trans["tran_amount"] > upper]
df_trans_outliers
# Out:
#         tran_id  cust_id   tran_date  tran_amount  platform  \
# 26           27      380  2023-01-01        61963   Shopify
# 49           50      287  2023-01-01        57869    Amazon
# 94           95      770  2023-01-01        52881      Ebay
# 104         105      549  2023-01-01        58574  Flipkart
# 113         114      790  2023-01-01        51669   Shopify
# ...         ...      ...         ...          ...       ...
# 499742   499743      868  2023-09-05        55131    Meesho
# 499888   499889      614  2023-09-05        59679    Meesho
# 499900   499901      811  2023-09-05        60184  Flipkart
# 499966   499967      662  2023-09-05        54678    Meesho
# 499996   499997      569  2023-09-05        53022    Meesho
#
#               product_category payment_type
# 26      Beauty & Personal Care  Credit Card
# 49                Toys & Games         Gpay
# 94          Kitchen Appliances  Credit Card
# 104          Fashion & Apparel         Gpay
# 113         Kitchen Appliances  Credit Card
# ...                        ...          ...
# 499742       Fashion & Apparel         Gpay
# 499888       Fashion & Apparel  Net Banking
# 499900                  Sports   Debit Card
# 499966                  Sports         Gpay
# 499996       Fashion & Apparel  Net Banking
#
# [25000 rows x 7 columns]

# %%
df_trans[df_trans["tran_amount"] < upper].tran_amount.max()
# Out:
# np.int64(999)

# %%
df_trans[df_trans["tran_amount"] > upper].tran_amount.min()
# Out:
# np.int64(50000)

# %%
df_trans_outliers["tran_amount"].value_counts().sum()
# Out:
# np.int64(25000)

# %%
df_trans_normal = df_trans[df_trans["tran_amount"] < upper]
df_trans_normal
# Out:
#         tran_id  cust_id   tran_date  tran_amount  platform  \
# 0             1      705  2023-01-01           63  Flipkart
# 1             2      385  2023-01-01           99   Alibaba
# 2             3      924  2023-01-01          471   Shopify
# 3             4      797  2023-01-01           33   Shopify
# 4             5      482  2023-01-01           68    Amazon
# ...         ...      ...         ...          ...       ...
# 499994   499995      679  2023-09-05           59      Ebay
# 499995   499996      791  2023-09-05           43    Amazon
# 499997   499998       57  2023-09-05          224    Amazon
# 499998   499999      629  2023-09-05          538  Flipkart
# 499999   500000      392  2023-09-05          346    Amazon
#
#               product_category payment_type
# 0                  Electronics      Phonepe
# 1            Fashion & Apparel  Credit Card
# 2                       Sports      Phonepe
# 3            Fashion & Apparel         Gpay
# 4            Fashion & Apparel  Net Banking
# ...                        ...          ...
# 499994  Beauty & Personal Care         Gpay
# 499995                   Books      Phonepe
# 499997        Garden & Outdoor      Phonepe
# 499998              Home Decor         Gpay
# 499999      Kitchen Appliances  Net Banking
#
# [475000 rows x 7 columns]

# %%
df_product_wise_mean = df_trans_normal.groupby(df_trans_normal.product_category)["tran_amount"].mean()
df_product_wise_mean
# Out:
# product_category
# Beauty & Personal Care     92.167205
# Books                      29.553515
# Electronics               510.172685
# Fashion & Apparel          64.553463
# Garden & Outdoor          125.630277
# Home Decor                302.487561
# Kitchen Appliances        176.773288
# Sports                    269.181631
# Toys & Games               50.333298
# Name: tran_amount, dtype: float64

# %%
df_trans.loc[df_trans_outliers.index]
# Out:
#         tran_id  cust_id   tran_date  tran_amount  platform  \
# 26           27      380  2023-01-01        61963   Shopify
# 49           50      287  2023-01-01        57869    Amazon
# 94           95      770  2023-01-01        52881      Ebay
# 104         105      549  2023-01-01        58574  Flipkart
# 113         114      790  2023-01-01        51669   Shopify
# ...         ...      ...         ...          ...       ...
# 499742   499743      868  2023-09-05        55131    Meesho
# 499888   499889      614  2023-09-05        59679    Meesho
# 499900   499901      811  2023-09-05        60184  Flipkart
# 499966   499967      662  2023-09-05        54678    Meesho
# 499996   499997      569  2023-09-05        53022    Meesho
#
#               product_category payment_type
# 26      Beauty & Personal Care  Credit Card
# 49                Toys & Games         Gpay
# 94          Kitchen Appliances  Credit Card
# 104          Fashion & Apparel         Gpay
# 113         Kitchen Appliances  Credit Card
# ...                        ...          ...
# 499742       Fashion & Apparel         Gpay
# 499888       Fashion & Apparel  Net Banking
# 499900                  Sports   Debit Card
# 499966                  Sports         Gpay
# 499996       Fashion & Apparel  Net Banking
#
# [25000 rows x 7 columns]

# %%
df_trans.loc[df_trans_outliers.index , "tran_amount"] = df_trans_outliers["product_category"].map(df_product_wise_mean)
# Out:
# C:\Users\prath\AppData\Local\Temp\ipykernel_13220\624104051.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 92.16720517  50.33329759 176.77328782 ... 269.18163136 269.18163136
#   64.55346325]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_trans.loc[df_trans_outliers.index , "tran_amount"] = df_trans_outliers["product_category"].map(df_product_wise_mean)

# %%
df_trans.loc[df_trans_outliers.index]
# Out:
#         tran_id  cust_id   tran_date  tran_amount  platform  \
# 26           27      380  2023-01-01    92.167205   Shopify
# 49           50      287  2023-01-01    50.333298    Amazon
# 94           95      770  2023-01-01   176.773288      Ebay
# 104         105      549  2023-01-01    64.553463  Flipkart
# 113         114      790  2023-01-01   176.773288   Shopify
# ...         ...      ...         ...          ...       ...
# 499742   499743      868  2023-09-05    64.553463    Meesho
# 499888   499889      614  2023-09-05    64.553463    Meesho
# 499900   499901      811  2023-09-05   269.181631  Flipkart
# 499966   499967      662  2023-09-05   269.181631    Meesho
# 499996   499997      569  2023-09-05    64.553463    Meesho
#
#               product_category payment_type
# 26      Beauty & Personal Care  Credit Card
# 49                Toys & Games         Gpay
# 94          Kitchen Appliances  Credit Card
# 104          Fashion & Apparel         Gpay
# 113         Kitchen Appliances  Credit Card
# ...                        ...          ...
# 499742       Fashion & Apparel         Gpay
# 499888       Fashion & Apparel  Net Banking
# 499900                  Sports   Debit Card
# 499966                  Sports         Gpay
# 499996       Fashion & Apparel  Net Banking
#
# [25000 rows x 7 columns]

# %%
df_trans["tran_amount"].describe()
# Out:
# count    500000.000000
# mean        240.672998
# std         241.696597
# min           2.000000
# 25%          64.553463
# 50%         133.000000
# 75%         349.000000
# max         999.000000
# Name: tran_amount, dtype: float64

# %%
sns.histplot(df_trans ,x = "tran_amount", bins = 20 , kde = True)
plt.title("Transection amount vs No of Transcetions")
plt.ylabel("No of Transcetions")
plt.show()

# %%
df_merge.head()
# Out:
#    cust_id            name  gender   age location      occupation  \
# 0        1   Manya Acharya  Female  51.0     City  Business Owner
# 1        2   Anjali Pandey  Female  47.0     City      Consultant
# 2        3  Aaryan Chauhan    Male  21.0     City      Freelancer
# 3        4      Rudra Bali    Male  24.0    Rural      Freelancer
# 4        5    Advait Malik    Male  48.0     City      Consultant
#
#    annual_income marital_status age_group  credit_score  credit_utilisation  \
# 0       358211.0        Married     49-65           749            0.585171
# 1        65172.0         Single     26-48           587            0.107928
# 2        22378.0        Married     18-25           544            0.854807
# 3        33563.0        Married     18-25           504            0.336938
# 4        39406.0        Married     26-48           708            0.586151
#
#    outstanding_debt  credit_inquiries_last_6_months  credit_limit  \
# 0           19571.0                             0.0       40000.0
# 1            1250.0                             2.0        1250.0
# 2             513.0                             4.0        1000.0
# 3             224.0                             2.0        1000.0
# 4           18090.0                             2.0       40000.0
#
#   credit_score_range  credit_limit_mode
# 0            700-749            40000.0
# 1            550-599             1250.0
# 2            500-549             1000.0
# 3            500-549             1000.0
# 4            700-749            40000.0

# %%
df_merge_2 = pd.merge(df_merge , df_trans , on = "cust_id" , how  = 'inner')
df_merge_2.head()
# Out:
#    cust_id           name  gender   age location      occupation  \
# 0        1  Manya Acharya  Female  51.0     City  Business Owner
# 1        1  Manya Acharya  Female  51.0     City  Business Owner
# 2        1  Manya Acharya  Female  51.0     City  Business Owner
# 3        1  Manya Acharya  Female  51.0     City  Business Owner
# 4        1  Manya Acharya  Female  51.0     City  Business Owner
#
#    annual_income marital_status age_group  credit_score  ...  \
# 0       358211.0        Married     49-65           749  ...
# 1       358211.0        Married     49-65           749  ...
# 2       358211.0        Married     49-65           749  ...
# 3       358211.0        Married     49-65           749  ...
# 4       358211.0        Married     49-65           749  ...
#
#    credit_inquiries_last_6_months  credit_limit  credit_score_range  \
# 0                             0.0       40000.0             700-749
# 1                             0.0       40000.0             700-749
# 2                             0.0       40000.0             700-749
# 3                             0.0       40000.0             700-749
# 4                             0.0       40000.0             700-749
#
#    credit_limit_mode tran_id   tran_date  tran_amount  platform  \
# 0            40000.0    1283  2023-01-01         30.0   Shopify
# 1            40000.0    1382  2023-01-01         96.0    Amazon
# 2            40000.0    1521  2023-01-01         86.0    Meesho
# 3            40000.0    1576  2023-01-01        149.0    Amazon
# 4            40000.0    1757  2023-01-01         37.0  Flipkart
#
#          product_category payment_type
# 0       Fashion & Apparel  Net Banking
# 1                  Sports   Debit Card
# 2        Garden & Outdoor         Gpay
# 3  Beauty & Personal Care      Phonepe
# 4       Fashion & Apparel  Credit Card
#
# [5 rows x 22 columns]

# %%
fig , (ax1 , ax2) = plt.subplots( 1,2 ,figsize = (12,5))
sns.countplot(x='age_group',hue = "payment_type" ,data = df_merge_2 , ax = ax1)
ax1.set_title("Age wise payment type")

sns.countplot(x='age_group',hue = "product_category" ,data = df_merge_2 , ax = ax2)
ax2.set_title("Age wise product category")
plt.show()

# %%
age_wise_credit_limit_mean =  df_merge_2.groupby('age_group')['credit_limit'].mean()
age_wise_credit_limit_mean
# Out:
# C:\Users\prath\AppData\Local\Temp\ipykernel_13220\3139254507.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   age_wise_credit_limit_mean =  df_merge_2.groupby('age_group')['credit_limit'].mean()
# age_group
# 18-25     1146.855728
# 26-48    20609.837285
# 49-65    41781.734465
# Name: credit_limit, dtype: float64

# %%
transection_amt_mean = df_merge_2.groupby('age_group')['tran_amount'].mean()
# Out:
# C:\Users\prath\AppData\Local\Temp\ipykernel_13220\1497055260.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   transection_amt_mean = df_merge_2.groupby('age_group')['tran_amount'].mean()

# %%
fig , (ax1 , ax2  ) = plt.subplots( 1,2 ,figsize = (12,5))
sns.barplot(transection_amt_mean ,ax = ax1,ci=None, palette='tab10')
ax1.set_title("Age wise average transection amount")
sns.barplot(age_wise_credit_limit_mean ,ax = ax2 , ci=None, palette='tab10')
ax2.set_title("Age wise average credit limit")
plt.show()
# Out:
# C:\Users\prath\AppData\Local\Temp\ipykernel_13220\3810310286.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(transection_amt_mean ,ax = ax1,ci=None, palette='tab10')
# C:\Users\prath\AppData\Local\Temp\ipykernel_13220\3810310286.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(transection_amt_mean ,ax = ax1,ci=None, palette='tab10')
# C:\Users\prath\AppData\Local\Temp\ipykernel_13220\3810310286.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(age_wise_credit_limit_mean ,ax = ax2 , ci=None, palette='tab10')
# C:\Users\prath\AppData\Local\Temp\ipykernel_13220\3810310286.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(age_wise_credit_limit_mean ,ax = ax2 , ci=None, palette='tab10')

# %%
fig , (ax1,ax2) = plt.subplots( 1,2 ,figsize = (12,5))
age_wise_credit_score_mode =  df_merge_2.groupby('age_group')['credit_score'].apply( lambda x : x.mode().iloc[0])
sns.barplot(age_wise_credit_score_mode ,ci=None, palette='tab10',ax = ax1)
ax1.set_title("Age wise Credit score mode")
sns.countplot(x='age_group', hue='product_category', data=df_merge_2, palette='tab10', ax=ax2) 
ax2.set_title("Age-wise Product Category") 
plt.show()
# Out:
# C:\Users\prath\AppData\Local\Temp\ipykernel_13220\3314321872.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   age_wise_credit_score_mode =  df_merge_2.groupby('age_group')['credit_score'].apply( lambda x : x.mode().iloc[0])
# C:\Users\prath\AppData\Local\Temp\ipykernel_13220\3314321872.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(age_wise_credit_score_mode ,ci=None, palette='tab10',ax = ax1)
# C:\Users\prath\AppData\Local\Temp\ipykernel_13220\3314321872.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(age_wise_credit_score_mode ,ci=None, palette='tab10',ax = ax1)
